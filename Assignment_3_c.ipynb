# %% [markdown]
# <a href="https://colab.research.google.com/github/samiksha-nehe/honours/blob/main/Assignment_3_c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from keras.models import Sequential
from keras.layers.core import Dense

# %%
input = np.array([[0,0],[0,1],[1,0],[1,1]])
output = np.array([[0],[1],[1],[0]])

# %%
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['binary_accuracy'])

# %%
model.fit(input, output, epochs=6000, verbose=2)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 3501/6000
# 1/1 - 0s - loss: 2.1328e-05 - binary_accuracy: 1.0000
# Epoch 3502/6000
# 1/1 - 0s - loss: 2.1315e-05 - binary_accuracy: 1.0000
# Epoch 3503/6000
# 1/1 - 0s - loss: 2.1304e-05 - binary_accuracy: 1.0000
# Epoch 3504/6000
# 1/1 - 0s - loss: 2.1292e-05 - binary_accuracy: 1.0000
# Epoch 3505/6000
# 1/1 - 0s - loss: 2.1279e-05 - binary_accuracy: 1.0000
# Epoch 3506/6000
# 1/1 - 0s - loss: 2.1266e-05 - binary_accuracy: 1.0000
# Epoch 3507/6000
# 1/1 - 0s - loss: 2.1255e-05 - binary_accuracy: 1.0000
# Epoch 3508/6000
# 1/1 - 0s - loss: 2.1243e-05 - binary_accuracy: 1.0000
# Epoch 3509/6000
# 1/1 - 0s - loss: 2.1231e-05 - binary_accuracy: 1.0000
# Epoch 3510/6000
# 1/1 - 0s - loss: 2.1218e-05 - binary_accuracy: 1.0000
# Epoch 3511/6000
# 1/1 - 0s - loss: 2.1206e-05 - binary_accuracy: 1.0000
# Epoch 3512/6000
# 1/1 - 0s - loss: 2.1194e-05 - binary_accuracy: 1.0000
# Epoch 3513/6000
# ...

# %%
print("Round off Values: \n",model.predict(input).round())
print("Actual Values: \n",model.predict(input))
# Out:
# Round off Values:
#  [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Actual Values:
#  [[0.00233197]
#  [0.9977249 ]
#  [0.99772036]
#  [0.00227326]]
