# %% [markdown]
# <a href="https://colab.research.google.com/github/samiksha-nehe/honours/blob/main/Assignment_3_d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from keras.models import Sequential
from keras.layers.core import Dense

# %%
input = np.array([[1],[0]])
output = np.array([[0],[1]])

# %%
model = Sequential()
model.add(Dense(16, input_dim=1, activation='linear'))
model.add(Dense(1, activation='linear'))

# %%
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['binary_accuracy'])

# %%
model.fit(input, output, epochs=500, verbose=2)
# Out:
# Epoch 1/500
# 1/1 - 1s - loss: 0.5991 - binary_accuracy: 0.5000
# Epoch 2/500
# 1/1 - 0s - loss: 0.5920 - binary_accuracy: 0.5000
# Epoch 3/500
# 1/1 - 0s - loss: 0.5850 - binary_accuracy: 0.5000
# Epoch 4/500
# 1/1 - 0s - loss: 0.5780 - binary_accuracy: 0.5000
# Epoch 5/500
# 1/1 - 0s - loss: 0.5710 - binary_accuracy: 0.5000
# Epoch 6/500
# 1/1 - 0s - loss: 0.5641 - binary_accuracy: 0.5000
# Epoch 7/500
# 1/1 - 0s - loss: 0.5572 - binary_accuracy: 0.5000
# Epoch 8/500
# 1/1 - 0s - loss: 0.5504 - binary_accuracy: 0.5000
# Epoch 9/500
# 1/1 - 0s - loss: 0.5437 - binary_accuracy: 0.5000
# Epoch 10/500
# 1/1 - 0s - loss: 0.5370 - binary_accuracy: 0.5000
# Epoch 11/500
# 1/1 - 0s - loss: 0.5304 - binary_accuracy: 0.5000
# Epoch 12/500
# 1/1 - 0s - loss: 0.5238 - binary_accuracy: 0.5000
# Epoch 13/500
# 1/1 - 0s - loss: 0.5172 - binary_accuracy: 0.5000
# Epoch 14/500
# 1/1 - 0s - loss: 0.5108 - binary_accuracy: 0.5000
# Epoch 15/500
# 1/1 - 0s - loss: 0.5043 - binary_accuracy: 0.5000
# ...

# %%
print("Round off Values: \n",model.predict(input).round())
print("Actual Values: \n",model.predict(input))
# Out:
# Round off Values:
#  [[0.]
#  [1.]]
# Actual Values:
#  [[6.854534e-07]
#  [9.999993e-01]]
